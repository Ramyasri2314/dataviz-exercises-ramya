# %%
import pandas as pd
import plotly.express as px

# %%
pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (6.7.0)
# Requirement already satisfied: pandas in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (3.0.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (from plotly) (2.19.0)
# Requirement already satisfied: packaging in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (from plotly) (26.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/ramyasri/dataviz-exercises-ramya/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
fig = px.line(df, x="year", y="lifeExp", color="country")
fig.show()

# %%
fig = px.bar(df, x="continent", y="pop", color="continent")
fig.show()

# %%
fig = px.scatter(df, x="gdpPercap", y="lifeExp", color="continent")
fig.show()

# %%
git add .
git commit -m "lecture02 exercise completed"
git push
# Out:
#   Cell In[7], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
